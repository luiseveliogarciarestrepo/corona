# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_rows', 1000)

# %%
gompertz = pd.read_csv('/Users/Dr.LuisEvelioRestrepoGarcia/REPOS/Salida_Datos_Abiertos.csv', encoding = 'unicode_escape', engine ='python', sep=',', usecols= ['Caso', 'Fecha Not', 
                                                                        'Ciudad_municipio_nom', 
                                                                        'Departamento_nom'], 
                                                                        parse_dates=['Fecha Not'])

# %%
gompertz.sort_values(by=['Fecha Not'],inplace=True)

# %%
gompertz.columns
# Out:
# Index(['Caso', 'Fecha Not', 'Departamento_nom', 'Ciudad_municipio_nom'], dtype='object')

# %%
gompertz['Fecha Not']= gompertz['Fecha Not'].dt.floor('d')

# %%
gompertz
# Out:
#             Caso  Fecha Not Departamento_nom Ciudad_municipio_nom
# 2223        2224 2020-01-04     BARRANQUILLA         BARRANQUILLA
# 24713      24754 2020-01-04            VALLE                 CALI
# 1622        1623 2020-01-04           BOGOTA               BOGOTA
# 1623        1624 2020-01-04           BOGOTA               BOGOTA
# 1624        1625 2020-01-04           BOGOTA               BOGOTA
# ...          ...        ...              ...                  ...
# 1481999  1482040 2020-12-18            VALLE              PALMIRA
# 1482001  1482042 2020-12-18            VALLE           ROLDANILLO
# 1481788  1481829 2020-12-18            VALLE           EL CERRITO
# 1481805  1481846 2020-12-18            VALLE              PALMIRA
# 1481803  1481844 2020-12-18            VALLE              FLORIDA
#
# [1482072 rows x 4 columns]

# %%
df = pd.DataFrame(gompertz['Fecha Not']).loc[0]
df
# Out:
# Fecha Not   2020-02-03
# Name: 0, dtype: datetime64[ns]

# %%
a = gompertz.loc[0,'Fecha Not']

# %%
b = np.datetime64('today') 
b
# Out:
# numpy.datetime64('2020-12-23')

# %%
longitud = (b-a)/ np.timedelta64(1, 'D')
longitud=int(longitud)-1
longitud
# Out:
# 323

# %%
df_fechas = pd.DataFrame(df).transpose()
df_fechas
# Out:
#    Fecha Not
# 0 2020-02-03

# %%
df_fechas['Caso']=0

# %%
df_fechas
# Out:
#    Fecha Not  Caso
# 0 2020-02-03     0

# %%
pd.to_datetime([df_fechas.loc[0,'Fecha Not']])
# Out:
# DatetimeIndex(['2020-02-03'], dtype='datetime64[ns]', freq=None)

# %%
(np.datetime64(df_fechas.loc[0, 'Fecha Not']) + np.timedelta64(1,'D'))
# Out:
# numpy.datetime64('2020-02-04T00:00:00.000000')

# %%
for i in range(1,longitud):
    df_fechas.loc[(i)] = [(np.datetime64(df_fechas.loc[i-1, 'Fecha Not']) + np.timedelta64(1,'D')),0]

# %%
df_fechas
# Out:
#      Fecha Not  Caso
# 0   2020-02-03     0
# 1   2020-02-04     0
# 2   2020-02-05     0
# 3   2020-02-06     0
# 4   2020-02-07     0
# 5   2020-02-08     0
# 6   2020-02-09     0
# 7   2020-02-10     0
# 8   2020-02-11     0
# 9   2020-02-12     0
# 10  2020-02-13     0
# 11  2020-02-14     0
# 12  2020-02-15     0
# 13  2020-02-16     0
# 14  2020-02-17     0
# 15  2020-02-18     0
# 16  2020-02-19     0
# 17  2020-02-20     0
# 18  2020-02-21     0
# 19  2020-02-22     0
# 20  2020-02-23     0
# 21  2020-02-24     0
# 22  2020-02-25     0
# 23  2020-02-26     0
# 24  2020-02-27     0
# 25  2020-02-28     0
# 26  2020-02-29     0
# 27  2020-03-01     0
# 28  2020-03-02     0
# 29  2020-03-03     0
# 30  2020-03-04     0
# 31  2020-03-05     0
# 32  2020-03-06     0
# 33  2020-03-07     0
# 34  2020-03-08     0
# 35  2020-03-09     0
# 36  2020-03-10     0
# 37  2020-03-11     0
# 38  2020-03-12     0
# 39  2020-03-13     0
# 40  2020-03-14     0
# 41  2020-03-15     0
# ...

# %%
gompertz_Col=gompertz.append(df_fechas).sort_values(by=['Fecha Not'], ignore_index=True)

# %%
gompertz_Col
# Out:
#             Caso  Fecha Not Departamento_nom Ciudad_municipio_nom
# 0           2224 2020-01-04     BARRANQUILLA         BARRANQUILLA
# 1           5756 2020-01-04         CASANARE                YOPAL
# 2           2240 2020-01-04        ANTIOQUIA             MEDELLIN
# 3           2401 2020-01-04           TOLIMA               IBAGUE
# 4           3366 2020-01-04           BOGOTA               BOGOTA
# ...          ...        ...              ...                  ...
# 1482390  1481846 2020-12-18            VALLE              PALMIRA
# 1482391  1481844 2020-12-18            VALLE              FLORIDA
# 1482392        0 2020-12-19              NaN                  NaN
# 1482393        0 2020-12-20              NaN                  NaN
# 1482394        0 2020-12-21              NaN                  NaN
#
# [1482395 rows x 4 columns]

# %%
longitud = gompertz_Col['Caso'].size
longitud
# Out:
# 1482395

# %%
for i in range(0, longitud):
    if gompertz_Col.loc[i, 'Caso'] == 0:
        pass
    else:
        gompertz_Col.loc[i, 'Caso'] = 1

# %%
#pd.to_datetime(gompertz_Col.loc[237958,'Fecha Not'], format='%Y-%m-%d')
#gompertz_Col.loc[237958, 'Fecha Not']

# %%
gompertz_Col['Acumulados']= 0
gompertz_Col['Día número']=0
gompertz_Col['Penetración real']=0
gompertz_Col
# Out:
#          Caso  Fecha Not Departamento_nom Ciudad_municipio_nom  Acumulados  \
# 0           1 2020-01-04     BARRANQUILLA         BARRANQUILLA           0
# 1           1 2020-01-04         CASANARE                YOPAL           0
# 2           1 2020-01-04        ANTIOQUIA             MEDELLIN           0
# 3           1 2020-01-04           TOLIMA               IBAGUE           0
# 4           1 2020-01-04           BOGOTA               BOGOTA           0
# ...       ...        ...              ...                  ...         ...
# 1482390     1 2020-12-18            VALLE              PALMIRA           0
# 1482391     1 2020-12-18            VALLE              FLORIDA           0
# 1482392     0 2020-12-19              NaN                  NaN           0
# 1482393     0 2020-12-20              NaN                  NaN           0
# 1482394     0 2020-12-21              NaN                  NaN           0
#
#          Día número  Penetración real
# ...

# %%
gompertz_Col.shape
# Out:
# (1482395, 7)

# %%
gompertz_Col.loc[0, 'Acumulados']= gompertz_Col.loc[0, 'Caso']
for i in range(1, longitud):
    gompertz_Col.loc[i,'Acumulados'] = gompertz_Col.loc[i, 'Caso'] + gompertz_Col.loc[i-1, 'Acumulados']

# %%
gompertz_Col
# Out:
#          Caso  Fecha Not Departamento_nom Ciudad_municipio_nom  Acumulados  \
# 0           1 2020-01-04     BARRANQUILLA         BARRANQUILLA           1
# 1           1 2020-01-04         CASANARE                YOPAL           2
# 2           1 2020-01-04        ANTIOQUIA             MEDELLIN           3
# 3           1 2020-01-04           TOLIMA               IBAGUE           4
# 4           1 2020-01-04           BOGOTA               BOGOTA           5
# ...       ...        ...              ...                  ...         ...
# 1482390     1 2020-12-18            VALLE              PALMIRA     1482071
# 1482391     1 2020-12-18            VALLE              FLORIDA     1482072
# 1482392     0 2020-12-19              NaN                  NaN     1482072
# 1482393     0 2020-12-20              NaN                  NaN     1482072
# 1482394     0 2020-12-21              NaN                  NaN     1482072
#
#          Día número  Penetración real
# ...

# %%
gompertz_Colombia = gompertz_Col.groupby('Fecha Not')[['Caso', 'Ciudad_municipio_nom',
       'Departamento_nom', 'Acumulados', 'Día número',
       'Penetración real']].max()

# %%
gompertz_Colombia
# Out:
#             Caso Ciudad_municipio_nom Departamento_nom  Acumulados  \
# Fecha Not
# 2020-01-04     1            ZIPAQUIRA            VALLE         196
# 2020-01-05     1                YUMBO            VALLE         663
# 2020-01-06     1            ZIPAQUIRA            VALLE        2406
# 2020-01-07     1        ZONA BANANERA            VALLE        8684
# 2020-01-08     1        ZONA BANANERA           VAUPES       18149
# 2020-01-09     1        ZONA BANANERA          VICHADA       26355
# 2020-01-10     1            ZIPAQUIRA          VICHADA       33858
# 2020-01-11     1        ZONA BANANERA           VAUPES       39257
# 2020-01-12     1            ZIPAQUIRA          VICHADA       47347
# 2020-02-03     1                  NaN              NaN       47348
# 2020-02-04     1                  NaN              NaN       47514
# 2020-02-05     1                  NaN              NaN       47975
# 2020-02-06     1                  NaN              NaN       49627
# ...

# %%
gompertz_Colombia.reset_index(inplace=True)

# %%
longitud = gompertz_Colombia['Caso'].size
longitud
# Out:
# 332

# %%
gompertz_Colombia.columns
# Out:
# Index(['Fecha Not', 'Caso', 'Ciudad_municipio_nom', 'Departamento_nom',
#        'Acumulados', 'Día número', 'Penetración real'],
#       dtype='object')

# %%
gompertz_Colombia.loc[0, 'Día número'] = 1
for i in range(1, longitud):
    gompertz_Colombia.loc[i,'Día número'] = i+1
    gompertz_Colombia.loc[i,'Penetración real'] = gompertz_Colombia.loc[i, 'Acumulados']/ gompertz_Colombia.loc[longitud-1, 'Acumulados']

# %%
gompertz_Colombia
# Out:
#      Fecha Not  Caso Ciudad_municipio_nom Departamento_nom  Acumulados  \
# 0   2020-01-04     1            ZIPAQUIRA            VALLE         196
# 1   2020-01-05     1                YUMBO            VALLE         663
# 2   2020-01-06     1            ZIPAQUIRA            VALLE        2406
# 3   2020-01-07     1        ZONA BANANERA            VALLE        8684
# 4   2020-01-08     1        ZONA BANANERA           VAUPES       18149
# 5   2020-01-09     1        ZONA BANANERA          VICHADA       26355
# 6   2020-01-10     1            ZIPAQUIRA          VICHADA       33858
# 7   2020-01-11     1        ZONA BANANERA           VAUPES       39257
# 8   2020-01-12     1            ZIPAQUIRA          VICHADA       47347
# 9   2020-02-03     1                  NaN              NaN       47348
# 10  2020-02-04     1                  NaN              NaN       47514
# 11  2020-02-05     1                  NaN              NaN       47975
# ...

# %%
gompertz_Colombia.to_excel('GompertzCol.xlsx')

# %%
#import matplotlib.pyplot as plt
#from scipy.optimize import curve_fit
#import numpy as np

# %%
#def gompertz_model(x,a,b,c):
 #   return c*np.exp(-b*np.exp(-x/a))

#def func(x,a,b,c):
 #   return c*np.exp(-b*np.exp(-x/a))

# %%
#def func(x, a, b, c):
 #   return a * np.exp(-b * x) + c

# %%
#def expo_model(x,p,N0=3,x0=1):
 #   return N0*(1+p)**(x-x0)

#def logistic_model(x,a,b,c):
 #   return c/(1+np.exp(-(x-b)/a))

# %% [markdown]
# Define the data to be fit with some noise:

# %%
#xdata = gompertz_Colombia['Día número']
#y = func(xdata, gompertz_Colombia['Penetración real'])
#np.random.seed(1729)
#y_noise = 0.2 * np.random.normal(size=xdata.size)
#ydata = y + y_noise
#plt.plot(xdata, ydata, 'k-', label='data')

# %% [markdown]
# Define the data to be fit with some noise:

# %%
#popt, pcov = curve_fit(func, xdata, ydata)
#popt

#plt.plot(xdata, func(xdata, *popt), 'r-',
         #label='fit: a=%5.3f, b=%5.3f, c=%5.3f' % tuple(popt))

# %% [markdown]
# Constrain the optimization to the region of 0 <= a <= 3, 0 <= b <= 1 and 0 <= c <= 0.5:

# %%
#popt, pcov = curve_fit(func, xdata, ydata, bounds=(0, [3., 1., 0.5]))
#popt

#plt.plot(xdata, func(xdata, *popt), 'b--',
         #label='fit: a=%5.3f, b=%5.3f, c=%5.3f' % tuple(popt))

# %%
#plt.xlabel('x')
#plt.ylabel('y')
#plt.legend()
#plt.show()
